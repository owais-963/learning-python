# %%
! pip install qrcode[pil]
#pip install pillow
# Out:
# Collecting qrcode[pil]
#   Downloading qrcode-7.1.tar.gz (36 kB)
# Requirement already satisfied: colorama in c:\users\owais\anaconda3\lib\site-packages (from qrcode[pil]) (0.4.4)
# Requirement already satisfied: pillow in c:\users\owais\anaconda3\lib\site-packages (from qrcode[pil]) (8.0.1)
# Building wheels for collected packages: qrcode
#   Building wheel for qrcode (setup.py): started
#   Building wheel for qrcode (setup.py): finished with status 'done'
#   Created wheel for qrcode: filename=qrcode-7.1-py3-none-any.whl size=31972 sha256=a7d5e0e2e6cb256c93f0ec89a911db5e808257b5ad618757cf5785a04dde35f9
#   Stored in directory: c:\users\owais\appdata\local\pip\cache\wheels\33\d8\0a\56e9c6c7963ae82998d8c6f313eb5fece8232572af6cb55384
# Successfully built qrcode
# Installing collected packages: qrcode
# Successfully installed qrcode-7.1

# %%
import qrcode as qr
from PIL import Image as img

# %%
qr.make("https://github.com/lincolnloop/python-qrcode/blob/master/qrcode/image/pil.py")

# %%
import qrcode
qr = qrcode.QRCode(
    version=4,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=2,
)
qr.add_data('http://localhost:8888/notebooks/OneDrive/Desktop/Pythonfiles/QR%20Code.ipynb')
qr.make(fit=True)

img = qr.make_image(fill_color="white", back_color="black")

# %%
img

# %%
import qrcode
qr = qrcode.QRCode(
    version=5,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=5,
    border=5,
)
qr.add_data('https://www.google.com/search?q=qr+code&sxsrf=ALeKk02E7Njkxa-tsk4dYZOeiyRYQTRDiw:1625857034862&source=lnms&tbm=isch&sa=X&ved=2ahUKEwjOyZK41dbxAhW08uAKHc23AQEQ_AUoAXoECAEQAw&biw=1024&bih=625#imgrc=Bq_vWGnaGeKYzM')
qr.make(fit=True)

img = qr.make_image(fill_color="green", back_color="white")

# %%
img

# %%
#logo=img.open('C:\\Users\\owais\\OneDrive\\Desktop\\logo.png')
logo=img.open('l.png')
base_width=100
w_percent=base_width/float(logo.size[0])
height=int(float(logo.size[1])*float(w_percent))
logo=logo.resize((base_width,height))
logo.thumbnail(logo.size)

# %%
logo
# Out:
# <PIL.Image.Image image mode=RGB size=100x101 at 0x202ED8E83A0>

# %%
qr = qrcode.QRCode(
    #version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
  #  box_size=8,
   # border=2,
)

# %%
qr.add_data("https://drive.google.com/file/d/1BcY5ycNmfFBNsYaO830pV5klmJUFpCu9/view?usp=sharing")

# %%
QrCode=qr.make_image(fill_color="#ea80fb", back_color="white").convert("RGB")

# %%
position=((QrCode.size[0]-logo.size[0])//2,(QrCode.size[1]-logo.size[1])//2)

# %%
QrCode.paste(logo,position)

# %%
QrCode
# Out:
# <PIL.Image.Image image mode=RGB size=570x570 at 0x2028ABDF610>

# %%
position
# Out:
# (180, 180)

# %%
logo.thumbnail(logo.size)

# %%
logo
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x202ED9392B0>

# %%
# import modules
import qrcode
from PIL import Image

# taking image which user wants
# in the QR code center
Logo_link = 'g4g.jpg'

logo = Image.open(Logo_link)

# taking base width
basewidth = 100

# adjust image size
wpercent = (basewidth/float(logo.size[0]))
hsize = int((float(logo.size[1])*float(wpercent)))
logo = logo.resize((basewidth, hsize), Image.ANTIALIAS)
QRcode = qrcode.QRCode(
	error_correction=qrcode.constants.ERROR_CORRECT_H
)

# taking url or text
url = 'https://www.geeksforgeeks.org/'

# addingg URL or text to QRcode
QRcode.add_data(url)

# generating QR code
QRcode.make()

# taking color name from user
QRcolor = 'Green'

# adding color to QR code
QRimg = QRcode.make_image(
	fill_color=QRcolor, back_color="white").convert('RGB')

# set size of QR code
pos = ((QRimg.size[0] - logo.size[0]) // 2,
	(QRimg.size[1] - logo.size[1]) // 2)
QRimg.paste(logo, pos)

# save the QR code generated
QRimg.save('gfg_QR.png')

print('QR code generated!')
# Out:
# QR code generated!

# %%
QRimg
# Out:
# <PIL.Image.Image image mode=RGB size=410x410 at 0x202ED7F87F0>

# %%
img.open('g4g.jpg')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=900x900 at 0x2028A9035B0>
