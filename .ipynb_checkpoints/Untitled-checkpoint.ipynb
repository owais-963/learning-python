# %%
def add():
    print(num1 + num2)
num1=int(input("Enter a number "))
num2=int(input("Enter another number "))
add()
# Out:
# Enter a number 4
# Enter another number 5
# 9

# %%
import myapp

# %%
myapp.send_app()

# %%
def fullname(fname,mname,lname):
    print(fname + mname + lname)
    def fullname(fname,mname="",lname=""):

# %%
a=input("Enter Your  First Name ")
b=input("Enter your Middle Name ")
c=input("Enter your Last Name ")
fullname(fname=a,lname=c,mname=b)
# Out:
# Enter Your  First Name Owais
# Enter your Middle Name
# Enter your Last Name Arshad
# OwaisArshad

# %%
def fullname(fname,mname="",lname=""):
    print(fname+mname+lname)

# %%
fullname(fname,lname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-93f54a50addd> in <module>
# ----> 1 fullname(fname,lname)
#
# NameError: name 'fname' is not defined

# %%
fullname("Owais","Ali","Arshad")
# Out:
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# OwaisAliArshad
# ...

# %%
def fullName(first,midle,last):
    print(first+midle+last)

# %%
fullName('owais'," ali",' arshad')
# Out:
# owais ali arshad
